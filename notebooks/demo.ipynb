# %%
@time using Plots, DataFrames, Query, Parameters
# Out:
#   0.000352 seconds (2.27 k allocations: 120.547 KiB)

# %%
@time df = DataFrame(x = rand(30), y = rand(30))
# Out:
#   0.042568 seconds (49.59 k allocations: 2.785 MiB, 17.09% gc time)
# 30×2 DataFrame
# │ Row │ x         │ y         │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ 0.279498  │ 0.317648  │
# │ 2   │ 0.294172  │ 0.244472  │
# │ 3   │ 0.209223  │ 0.0915541 │
# │ 4   │ 0.791391  │ 0.738158  │
# │ 5   │ 0.998262  │ 0.645496  │
# │ 6   │ 0.145448  │ 0.373637  │
# │ 7   │ 0.76994   │ 0.425707  │
# │ 8   │ 0.449704  │ 0.282081  │
# │ 9   │ 0.697906  │ 0.77464   │
# │ 10  │ 0.60647   │ 0.845369  │
# ⋮
# │ 20  │ 0.899314  │ 0.726782  │
# │ 21  │ 0.868961  │ 0.692545  │
# │ 22  │ 0.989401  │ 0.575411  │
# │ 23  │ 0.041913  │ 0.606334  │
# │ 24  │ 0.181966  │ 0.714064  │
# │ 25  │ 0.915262  │ 0.485444  │
# │ 26  │ 0.696786  │ 0.0256945 │
# │ 27  │ 0.124504  │ 0.775788  │
# │ 28  │ 0.0466988 │ 0.50878   │
# │ 29  │ 0.610167  │ 0.641221  │
# │ 30  │ 0.298397  │ 0.852178  │

# %%
@time df2 = df |> @filter(_.x > 0.5) |> DataFrame;
# Out:
#   0.272588 seconds (753.31 k allocations: 38.939 MiB, 4.79% gc time)

# %%
@time plot(df2.x, df2.y)
# Out:
#   2.481988 seconds (8.40 M allocations: 413.418 MiB, 8.93% gc time)
# Plot{Plots.GRBackend() n=1}
